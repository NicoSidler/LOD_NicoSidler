# %% [markdown]
# ### Persons in the geographical space
#
# We present various methods of spatialising the birthplaces of our population.
#
# The data was prepared using the queries [documented on this page](https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/documentation/wikidata/data-analysis/da2-birth-places.sql)

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString
from shapely import wkt

import scipy.stats as stats
import math

from geopandas.tools import sjoin
#from geodatasets import get_path

# %%
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

import json

import numpy as np
import seaborn as sns
import math
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pprint
import csv


from shutil import copyfile

# %% [markdown]
# ## Geo data
#
# Documentation: [Geographical Information System](https://en.wikipedia.org/wiki/Geographic_information_system) (Wikipedia)
#
# <img src=./doc_images/DatendimensionenImGIS.jpg alt="geodata" width="50%">
# Par F Lamiot d'après [1] (GNUFDL) — source, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=3831140
#
#
# ### Source des données spatiales
# [Word Regions (ESRI)](https://hub.arcgis.com/datasets/a79a3e4dc55343b08543b1b6133bfb90/explore?location=-0.027457%2C0.000000%2C0.88). For personal use only, data under copyright !

# %%
world_filepath = 'geo_data/World_Regions_6144914380456424035.geojson'
## dataframe GeoPandas
world = gpd.read_file(world_filepath)
world.head()
# Out:
#    FID                 REGION          SQMI          SQKM  \
# 0    1         Asiatic Russia  4.987737e+06  1.291823e+07
# 1    2  Australia/New Zealand  3.077219e+06  7.969992e+06
# 2    3              Caribbean  8.919361e+04  2.310113e+05
# 3    4        Central America  9.576923e+05  2.480422e+06
# 4    5           Central Asia  1.612212e+06  4.175626e+06
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((158.88218 -54.71139, 158.87967...
# 2  MULTIPOLYGON (((-60.92305 10.79722, -60.94445 ...
# 3  MULTIPOLYGON (((-81.67847 7.38861, -81.64945 7...
# 4  POLYGON ((53.90564 37.35086, 53.67731 37.33536...

# %% [markdown]
# ### Basic GIS notions
#
# * [Geographic information system - GIS](https://en.wikipedia.org/wiki/Geographic_information_system)
# * [Geoid](https://en.wikipedia.org/wiki/Geoid)
# * [Earth ellipsoid](https://en.wikipedia.org/wiki/Earth_ellipsoid): WGS84
# * [Spatial reference system - SRS/CRS](https://en.wikipedia.org/wiki/Spatial_reference_system)
# * [EPSG Geodetic Parameter Dataset](https://en.wikipedia.org/wiki/EPSG_Geodetic_Parameter_Dataset): EPSG:4326, EPSG:3857, EPSG:9989

# %%
### Inspect the projection
pprint.pprint(world.crs)
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
### Draw the world map

## GeoPandas documentation
# https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.plot.html

# If we want to exclude the Antarctic region
world.clip([-180.0, -10.0, 180.0, 90.0])

ax = world.plot(color="DarkCyan", alpha=0.2, edgecolor="black", figsize=(12,9))

# If we want to exclude the Antarctic region
ax.set_xlim(-170,180)
ax.set_ylim(-65, 90)


plt.show()

# %% [markdown]
# ## Import the data
#
# The data is available in the da_data directory and was prepared using the query [documented on this page](../../documentation/wikidata/data-analysis/da1-distribution-of-births-in-time.md)

# %%
## create variable declaring the path to the data
path_to_data = 'da_data/da2-birth-place.csv'

# %%
## creating a Pandas Dataframe (data container in form of a table) 
df_p = pd.read_csv(path_to_data, sep=",", encoding="utf-8", header=0)
df_p.columns = ['uriPer', 'labelPer', 'birthYear', 'gender', 'labelPlace',
                'geometry','uriPlace']

## first rows of the dataframe
df_p.head()
# Out:
#                                       uriPer          labelPer  birthYear  \
# 0    http://www.wikidata.org/entity/Q1000087       Horst Baier       1933
# 1    http://www.wikidata.org/entity/Q1000348        Rainer Neu       1950
# 2    http://www.wikidata.org/entity/Q1000622      Zsuzsa Ferge       1931
# 3  http://www.wikidata.org/entity/Q100146726  Nicolas Bourgoin       1962
# 4    http://www.wikidata.org/entity/Q1002184       Félix Somló       1873
#
#    gender  labelPlace                    geometry  \
# 0    male        Brno  POINT(16.608333 49.195278)
# 1    male       Wesel   POINT(6.617778 51.658611)
# 2  female    Budapest  POINT(19.040833 47.498333)
# 3    male       Paris   POINT(2.352222 48.856667)
# 4    male  Bratislava  POINT(17.112778 48.144722)
#
#                                 uriPlace
# 0  http://www.wikidata.org/entity/Q14960
# 1   http://www.wikidata.org/entity/Q4011
# 2   http://www.wikidata.org/entity/Q1781
# 3     http://www.wikidata.org/entity/Q90
# 4   http://www.wikidata.org/entity/Q1780

# %%
## Basic infor about the DataFrame
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9825 entries, 0 to 9824
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uriPer      9825 non-null   object
#  1   labelPer    9825 non-null   object
#  2   birthYear   9825 non-null   int64
#  3   gender      9784 non-null   object
#  4   labelPlace  9825 non-null   object
#  5   geometry    9825 non-null   object
#  6   uriPlace    9825 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 537.4+ KB

# %% [markdown]
# ## Inspect the data

# %%
### Add column names and inspect length of dataframe

print('Number: ',len(df_p))
df_p.iloc[10:13,:]
# Out:
# Number:  9825
#                                        uriPer          labelPer  birthYear  \
# 10  http://www.wikidata.org/entity/Q100328765  Fátima Patriarca       1944
# 11  http://www.wikidata.org/entity/Q100366657     Martín Tanaka       1965
# 12  http://www.wikidata.org/entity/Q100375832    Ronald Voullié       1952
#
#     gender labelPlace                      geometry  \
# 10  female      Couço    POINT(-8.271990 38.936040)
# 11    male       Lima  POINT(-77.037500 -12.060000)
# 12    male     Bremen     POINT(8.807222 53.075833)
#
#                                    uriPlace
# 10  http://www.wikidata.org/entity/Q1137951
# 11     http://www.wikidata.org/entity/Q2868
# 12    http://www.wikidata.org/entity/Q24879

# %% [markdown]
# ### Treat multiple birth places
#
# Verify that persons are unique:
# * are there some persons with multiple birth places, etc.?
#   * If Pandas *is_unique* method: 'true' they are unique, so no multiple.
#   * If 'false': multiple rows per person
# * If you have multiple persons go back to the SQL part and clean up using GROUP BY -> MIN

# %%
### Tests if the values in the column are unique
# If unique result : True (boolean value not string !)
is_unique=df_p.uriPer.is_unique
print(is_unique)
# Out:
# True

# %% [markdown]
# ## Group and map birth places
#
# "Well-known text (WKT) is a text markup language for representing vector geometry objects" ([Wikipedia](https://en.wikipedia.org/wiki/Well-known_text_representation_of_geometry))

# %%
### Group and count the number of persons per birth place
p_gr = df_p.groupby(by=['uriPlace', 'labelPlace', 'geometry'], as_index=False).size()
p_gr.columns=['uriPlace', 'labelPlace', 'geometry', 'size']
p_gr.sort_values('size', ascending=False).head()
# Out:
#                                   uriPlace     labelPlace  \
# 1132  http://www.wikidata.org/entity/Q1781       Budapest
# 3544    http://www.wikidata.org/entity/Q64         Berlin
# 232   http://www.wikidata.org/entity/Q1085         Prague
# 2036   http://www.wikidata.org/entity/Q270         Warsaw
# 3428    http://www.wikidata.org/entity/Q60  New York City
#
#                          geometry  size
# 1132   POINT(19.040833 47.498333)   149
# 3544   POINT(13.383333 52.516667)   148
# 232    POINT(14.421389 50.087500)   122
# 2036   POINT(21.011111 52.230000)   115
# 3428  POINT(-74.006111 40.712778)   107

# %%
### Try first to convert WKT into Point Geometry
# using a geopandas feature
try:
    p_gr['geometry'] = p_gr['geometry'].apply(wkt.loads)
except Exception as e:
    print(e)

# %%
### there are wrong values in the data: find them
# all the rows where the geometry field does not contain the string 'POINT'
df_p.loc[~df_p.geometry.str.contains('POINT')]
# Out:
# Empty DataFrame
# Columns: [uriPer, labelPer, birthYear, gender, labelPlace, geometry, uriPlace]
# Index: []

# %%
### Drop the rows with the wrong value
df_p=df_p.loc[df_p.geometry.str.contains('POINT')]

# %%
### Re-do grouping after cleaning up
p_gr = df_p.groupby(by=['uriPlace', 'labelPlace', 'geometry'], as_index=False).size()
p_gr.columns=['uriPlace', 'labelPlace', 'geometry', 'number']
p_gr.sort_values('number', ascending=False).head(2)
# Out:
#                                   uriPlace labelPlace  \
# 1132  http://www.wikidata.org/entity/Q1781   Budapest
# 3544    http://www.wikidata.org/entity/Q64     Berlin
#
#                         geometry  number
# 1132  POINT(19.040833 47.498333)     149
# 3544  POINT(13.383333 52.516667)     148

# %%
### Create a dataframe with the POINT geometry
# https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html
birth_gdf = gpd.GeoDataFrame(
    p_gr, 
    ### Use this if no conversion before to geometry
    ## Cf. above:  p_gr['geometry'].apply(wkt.loads)
    geometry=gpd.GeoSeries.from_wkt(p_gr.geometry), 
    crs=4326
)

birth_gdf.sort_values('number', ascending=False).head(2)
# Out:
#                                   uriPlace labelPlace  \
# 1132  http://www.wikidata.org/entity/Q1781   Budapest
# 3544    http://www.wikidata.org/entity/Q64     Berlin
#
#                        geometry  number
# 1132  POINT (19.04083 47.49833)     149
# 3544  POINT (13.38333 52.51667)     148

# %%
### The Python class of the object changed 
# WKT strings are now points
print(p_gr.geometry.dtype, '->', birth_gdf.geometry.dtype)
# Out:
# object -> geometry

# %%
### Inspect the projection
pprint.pprint(birth_gdf.crs)
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
### Draw the world map


ax = world.plot(color="LightCyan", alpha=0.3, 
                edgecolor="black", linewidth=2, figsize=(64,48))

# If we want to exclude the Antarctic region
ax.set_xlim(-170,180)
ax.set_ylim(-60, 80)

# We can now plot our ``GeoDataFrame``.
birth_gdf.plot(ax=ax, color="DarkRed", markersize='number', alpha=0.5)
# Add labels where number > 100
for _, row in birth_gdf[birth_gdf['number'] > 50].iterrows():
    ax.annotate(
        text=row['labelPlace'],          # e.g. "Boston"
        xy=(row.geometry.x, row.geometry.y),
        xytext=(5, 5),              # offset in points
        textcoords="offset points",
        fontsize=7,
        color="Black",
        bbox=dict(
            boxstyle="round,pad=0.2",
            facecolor="white",
            edgecolor="none",
            alpha=0.7
        )
    )

f_address = "images/birth_places_geopandas.png"
plt.savefig(f_address)
plt.show()
print('Done -> inspect picture')
plt.close()
# Out:
# Done -> inspect picture

# %% [markdown]
# ## Experiment with different kinds of maps

# %%
birth_gdf.head(1)
# Out:
#                               uriPlace labelPlace                    geometry  \
# 0  http://www.wikidata.org/entity/Q100     Boston  POINT (-71.05778 42.36028)
#
#    number
# 0      21

# %%
### Create columns for long / lat
birth_gdf['long'] = birth_gdf['geometry'].x
birth_gdf['lat'] = birth_gdf['geometry'].y
birth_gdf.head(1)
# Out:
#                               uriPlace labelPlace                    geometry  \
# 0  http://www.wikidata.org/entity/Q100     Boston  POINT (-71.05778 42.36028)
#
#    number       long        lat
# 0      21 -71.057778  42.360278

# %%
birth_gdf_plus1 = birth_gdf.loc[birth_gdf.number>1]
print(birth_gdf_plus1[["lat", "long"]].head(10))
print(birth_gdf_plus1[["lat", "long"]].describe())
print(birth_gdf_plus1.crs)
# Out:
#           lat       long
# 0   42.360278 -71.057778
# 3   49.431397  15.223389
# 4   50.162871  16.274955
# 17  46.768910  23.590660
# 38  49.101478  16.377529
# 42  61.291667  28.816667
# 43  46.550000  15.633333
# 48  46.229092  15.264129
# 54  49.714679  16.265479
# 57  45.547543  13.730657
#                lat         long
# count  1070.000000  1070.000000
# mean     41.202461     5.737461
# std      18.544054    51.521367
# min     -53.162500  -157.857222
# 25%      39.530446    -0.470764
# 50%      46.995139     9.942778
# 75%      50.814910    18.991667
# max      68.966667   174.777222
# EPSG:4326

# %%
### We explore different ways of normalizing the data,
## i.e. diminishing the difference between high and low values
# p_size = [int(s/10+2) for s in birth_gdf_plus1['number']]
# p_size = [int(s) for s in birth_gdf_plus1['number']]
p_size = [(math.log(s)) for s in birth_gdf_plus1['number']]
max(p_size)
# Out:
# 5.003946305945459

# %%
fig = px.scatter_map(
    birth_gdf_plus1, lat="lat", lon="long", size=p_size,
    hover_name="labelPlace", hover_data=["number"],
    opacity=0.8, zoom=3.5,
    center=dict(lon=8.5, lat=47),
    height=1000
)

fig.update_traces(marker=dict(color="GreenYellow", sizemin=0.2))

fig.update_layout(
    map=dict(
        style={
            "version": 8,
            "sources": {
                "usgs": {
                    "type": "raster",
                    "tiles": ["https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"],
                    "tileSize": 256
                }
            },
            "layers": [{
                "id": "usgs-layer",
                "type": "raster",
                "source": "usgs"
            }]
        },
        center=dict(lon=8.5, lat=47),
        zoom=3.5
    )
)

#fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
f_address = "interactive_images/birth_places_geological_survey.html"
fig.write_html(f_address)
print('Done -> inspect picture')
# fig.show()
plt.close()
# Out:
# Done -> inspect picture

# %%
### Open the world regions ESRI file in geojson format (and not dataframe)
with open('geo_data/World_Regions_6144914380456424035.geojson') as f:
    geojson = json.load(f)

geojson['features'][3]['properties']
# Out:
# {'FID': 4,
#  'REGION': 'Central America',
#  'SQMI': 957692.30734,
#  'SQKM': 2480421.615}

# %%
### 

p_size = [int(s/10+2) for s in birth_gdf_plus1['number']]

fig = px.scatter_map(birth_gdf_plus1, lat="lat", lon="long", size=p_size, 
                     hover_name="labelPlace", 
                        color_discrete_sequence=["DodgerBlue"],  zoom=3.5,
                        center=dict(lon=8.5, lat=47),height=600,
                        opacity=0.9)
fig.update_layout(
    map_style="white-bg",
    map_layers=[
        {
            "below": 'traces',
            "sourcetype": "geojson",
            "type":"line",
            "sourceattribution": "ESRI",
            "source": geojson,
            "line": {"width": 0.5},
        }
      ])

f_address = "interactive_images/birth_places_regions.html"
fig.write_html(f_address)
#fig.show()

# %% [markdown]
# ### Plot the world as a sphere

# %%
### Plot on world as a sphere

lon = birth_gdf["long"]
lat= birth_gdf["lat"]
label= birth_gdf["labelPlace"]
size=[s/10 + 3 for s in birth_gdf["number"]]


# Create the figure
fig = go.Figure(data=go.Scattergeo(
    lon=lon,
    lat=lat,
    mode='markers+text',
    marker=dict(size=size,
                color='red'),
    hovertext=label,
    textposition='top center',
    hoverinfo='text',
    hoverlabel=dict(
        bgcolor='white',
        font_size=12,
        font_family='Arial'
    )
))

# Set the projection to orthogonal
fig.update_layout(
    width=800, 
    height=800,
    geo=dict(
        projection=dict(
            type='orthographic'
        )
    )
)

f_address = "interactive_images/birth_places_globus.html"
fig.write_html(f_address)
# Show the plot
#fig.show()

# %% [markdown]
# ### Join regions and inspect
#
# We use here spatial joins and associate a region to each place

# %%
birth_gdf.loc[birth_gdf.labelPlace.str.contains('Petersburg') |
              birth_gdf.labelPlace.str.contains('Moscow')
              ].sort_values('number', ascending=False).head(10)
# Out:
#                                  uriPlace        labelPlace  \
# 3577  http://www.wikidata.org/entity/Q649            Moscow
# 3606  http://www.wikidata.org/entity/Q656  Saint Petersburg
#
#                       geometry  number       long        lat
# 3577  POINT (37.6175 55.75056)      88  37.617500  55.750556
# 3606    POINT (30.31667 59.95)      31  30.316667  59.950000

# %%
### GeoPandas spatial join

w_birth_gdf= birth_gdf.sjoin(world)
w_birth_gdf.iloc[[1,5,10]]
# Out:
#                                    uriPlace labelPlace  \
# 1   http://www.wikidata.org/entity/Q1000052    Coruche
# 5     http://www.wikidata.org/entity/Q10002   Enschede
# 10  http://www.wikidata.org/entity/Q1000642     Summit
#
#                     geometry  number       long      lat  index_right  FID  \
# 1     POINT (-8.53333 38.95)       1  -8.533333  38.9500           18   19
# 5     POINT (6.8925 52.2225)       1   6.892500  52.2225           21   22
# 10  POINT (-74.3647 40.7156)       1 -74.364700  40.7156           22   23
#
#               REGION          SQMI          SQKM
# 1    Southern Europe  5.030151e+05  1.302808e+06
# 5     Western Europe  4.233073e+05  1.096365e+06
# 10  Northern America  8.292643e+06  2.147793e+07

# %%
### Number of regions
print(len(world))
world.head(1)
# Out:
# 25
#    FID          REGION          SQMI         SQKM  \
# 0    1  Asiatic Russia  4.987737e+06  12918232.32
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
### Count by region (sum number of each place in the region)
swb = w_birth_gdf.groupby(['FID','REGION'], as_index=False)['number'].sum()
#swb = swb.set_index('FID', drop=False)
print(len(swb))
swb.sort_values('number', ascending=False).head(24)
# Out:
# 21
#     FID                 REGION  number
# 18   22         Western Europe    2746
# 7     8         Eastern Europe    1781
# 15   19        Southern Europe    1278
# 19   23       Northern America    1003
# 11   15          South America     647
# 20   24        Northern Europe     486
# 6     7           Eastern Asia     464
# 8     9        European Russia     283
# 17   21           Western Asia     196
# 14   18          Southern Asia     151
# 10   13        Northern Africa     112
# 3     4        Central America     103
# 0     1         Asiatic Russia      53
# 1     2  Australia/New Zealand      47
# 16   20         Western Africa      43
# 2     3              Caribbean      42
# 12   16      Southeastern Asia      34
# 9    12          Middle Africa      24
# 13   17        Southern Africa      20
# 4     5           Central Asia      19
# 5     6         Eastern Africa      12

# %%
### Find places in European Russia with most births 
w_birth_gdf.loc[w_birth_gdf.FID==9].sort_values('number',ascending=False).head(2)
# Out:
#                                  uriPlace        labelPlace  \
# 3577  http://www.wikidata.org/entity/Q649            Moscow
# 3606  http://www.wikidata.org/entity/Q656  Saint Petersburg
#
#                       geometry  number       long        lat  index_right  \
# 3577  POINT (37.6175 55.75056)      88  37.617500  55.750556            8
# 3606    POINT (30.31667 59.95)      31  30.316667  59.950000            8
#
#       FID           REGION          SQMI         SQKM
# 3577    9  European Russia  1.541719e+06  3993050.089
# 3606    9  European Russia  1.541719e+06  3993050.089

# %%
### Normal Pandas join: add polygons to aggregated regions 
geom_swb=pd.merge(world, swb, left_on='FID', right_on='FID', 
                  how='left')

geom_swb.head(3)
# Out:
#    FID               REGION_x          SQMI          SQKM  \
# 0    1         Asiatic Russia  4.987737e+06  1.291823e+07
# 1    2  Australia/New Zealand  3.077219e+06  7.969992e+06
# 2    3              Caribbean  8.919361e+04  2.310113e+05
#
#                                             geometry               REGION_y  \
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...         Asiatic Russia
# 1  MULTIPOLYGON (((158.88218 -54.71139, 158.87967...  Australia/New Zealand
# 2  MULTIPOLYGON (((-60.92305 10.79722, -60.94445 ...              Caribbean
#
#    number
# 0    53.0
# 1    47.0
# 2    42.0

# %%
"""grp_geo = gpd.GeoDataFrame(
    geom_reg_per, 
    crs=4326
)
"""
### simplify geometry 
## https://www.statology.org/how-to-simplify-geographic-data-using-geopandas/
geom_swb["geometry"] = (
    geom_swb.simplify(tolerance=0.5)
)

# %%
### range
max = geom_swb.number.max()

# Create the choropleth map
fig = px.choropleth_map(
    geom_swb,
    geojson=geom_swb.__geo_interface__,
    map_style='white-bg',
    locations=geom_swb.index,
    color='number',  # Replace with your actual column name
    color_continuous_scale='Blues',
    range_color=(0, max),  # Replace with your actual range
    zoom=1,
    hover_name='REGION_x',
    center={'lat': 47, 'lon': 8.5},
    height=600,
    width=800

)

f_address = "interactive_images/birth_places_regions_choropleth.html"
fig.write_html(f_address)
# Show the plot
#fig.show()

# %% [markdown]
# ## Analyse using periods

# %%
### Imputed activity periods
l_10 = list(range(1781, 1991, 10))
print(l_10[:5],l_10[-5:])
# Out:
# [1781, 1791, 1801, 1811, 1821] [1941, 1951, 1961, 1971, 1981]

# %%
### convert birthYear to integer
df_p.birthYear = df_p.birthYear.apply(lambda x : int(x))

# %%
try:
    df_p = df_p.drop('len_coord', axis=1)
except Exception as e:
    print(e)
df_p.head(2)
# Out:
# "['len_coord'] not found in axis"
#                                     uriPer     labelPer  birthYear gender  \
# 0  http://www.wikidata.org/entity/Q1000087  Horst Baier       1933   male
# 1  http://www.wikidata.org/entity/Q1000348   Rainer Neu       1950   male
#
#   labelPlace                    geometry  \
# 0       Brno  POINT(16.608333 49.195278)
# 1      Wesel   POINT(6.617778 51.658611)
#
#                                 uriPlace
# 0  http://www.wikidata.org/entity/Q14960
# 1   http://www.wikidata.org/entity/Q4011

# %%
### fonction pd.cut : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html
# On ajoute une nouvelle colonne qui contient la période sur la base de la liste précédente
# et de la valeur de l'année
df_p['periods'] = pd.cut(df_p['birthYear'], l_10, right=False)

### Transformer le code ajouté pour qu'il soit plus lisible
# noter qu'on a arrondi les valeurs
df_p['periods'] = df_p['periods'].apply(lambda x : str(int(x.left))+'-'+ str(int(x.right)-1))

df_p=df_p.sort_values(by='periods')

# Inspection
df_p.iloc[[1,5,10]]
# Out:
#                                        uriPer             labelPer  birthYear  \
# 6989  http://www.wikidata.org/entity/Q5400003  Adolphe Hugentobler       1810
# 7904  http://www.wikidata.org/entity/Q6320673       Józef Supiński       1804
# 2698  http://www.wikidata.org/entity/Q1319570         Eugène Buret       1810
#
#      gender  labelPlace                    geometry  \
# 6989   male  Cortaillod   POINT(6.847930 46.943990)
# 7904   male     Romaniv  POINT(24.341389 49.709445)
# 2698   male      Troyes   POINT(4.078056 48.298889)
#
#                                      uriPlace    periods
# 6989    http://www.wikidata.org/entity/Q70308  1801-1810
# 7904  http://www.wikidata.org/entity/Q4397209  1801-1810
# 2698     http://www.wikidata.org/entity/Q5489  1801-1810

# %%
p_gr_per = df_p.groupby(by=['uriPlace', 'labelPlace', 'periods', 'geometry'], observed=True, as_index=False).size()
p_gr_per.columns=['uriPlace', 'labelPlace', 'period', 'coordinates', 'size']
#p_grp.geometry = gpd.GeoSeries.from_wkt(p_gr["coordinates"])
p_gr_per=p_gr_per.sort_values(by='period')
p_gr_per.head()
# Out:
#                                      uriPlace             labelPlace  \
# 4465  http://www.wikidata.org/entity/Q4397209                Romaniv
# 1972   http://www.wikidata.org/entity/Q183263  Prince William County
# 5097     http://www.wikidata.org/entity/Q5489                 Troyes
# 6428       http://www.wikidata.org/entity/Q90                  Paris
# 5785    http://www.wikidata.org/entity/Q70308             Cortaillod
#
#          period                  coordinates  size
# 4465  1801-1810   POINT(24.341389 49.709445)     1
# 1972  1801-1810  POINT(-77.480000 38.700000)     1
# 5097  1801-1810    POINT(4.078056 48.298889)     1
# 6428  1801-1810    POINT(2.352222 48.856667)     1
# 5785  1801-1810    POINT(6.847930 46.943990)     1

# %%
### Create a Geopandas geometry column
# https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html
birth_p_grp = gpd.GeoDataFrame(
    p_gr_per, 
    ### Here we use it
    geometry=gpd.GeoSeries.from_wkt(p_gr_per.coordinates), crs=4326
)

birth_p_grp.head(3)
# Out:
#                                      uriPlace             labelPlace  \
# 4465  http://www.wikidata.org/entity/Q4397209                Romaniv
# 1972   http://www.wikidata.org/entity/Q183263  Prince William County
# 5097     http://www.wikidata.org/entity/Q5489                 Troyes
#
#          period                  coordinates  size                   geometry
# 4465  1801-1810   POINT(24.341389 49.709445)     1  POINT (24.34139 49.70944)
# 1972  1801-1810  POINT(-77.480000 38.700000)     1        POINT (-77.48 38.7)
# 5097  1801-1810    POINT(4.078056 48.298889)     1   POINT (4.07806 48.29889)

# %%
### Create columns for long / lat
birth_p_grp['long'] = birth_p_grp['geometry'].x
birth_p_grp['lat'] = birth_p_grp['geometry'].y
birth_p_grp.head()
# Out:
#                                      uriPlace             labelPlace  \
# 4465  http://www.wikidata.org/entity/Q4397209                Romaniv
# 1972   http://www.wikidata.org/entity/Q183263  Prince William County
# 5097     http://www.wikidata.org/entity/Q5489                 Troyes
# 6428       http://www.wikidata.org/entity/Q90                  Paris
# 5785    http://www.wikidata.org/entity/Q70308             Cortaillod
#
#          period                  coordinates  size                   geometry  \
# 4465  1801-1810   POINT(24.341389 49.709445)     1  POINT (24.34139 49.70944)
# 1972  1801-1810  POINT(-77.480000 38.700000)     1        POINT (-77.48 38.7)
# 5097  1801-1810    POINT(4.078056 48.298889)     1   POINT (4.07806 48.29889)
# 6428  1801-1810    POINT(2.352222 48.856667)     1   POINT (2.35222 48.85667)
# 5785  1801-1810    POINT(6.847930 46.943990)     1   POINT (6.84793 46.94399)
#
#            long        lat
# 4465  24.341389  49.709445
# 1972 -77.480000  38.700000
# 5097   4.078056  48.298889
# 6428   2.352222  48.856667
# 5785   6.847930  46.943990

# %%
# now just plot it on a map with evolution by time
# https://plotly.com/python/animations/
# https://plotly.com/python/scatter-plots-on-maps/

# np.log(s) * 1000
size = [s*5 if s != 0 else 0 for s in birth_p_grp["size"]]




fig = px.scatter_geo(
    birth_p_grp,
    lon="long",
    lat="lat",
    size=size,
    hover_name = "labelPlace",
    animation_frame= "period",
    width=1400, height=600,
    color_discrete_sequence=['red'],
    title="Evolution of birth places through time"
)
    
fig.layout.updatemenus[0].buttons[0].args[1]["frame"] = {"duration": 1500, "redraw": True}
fig.layout.updatemenus[0].buttons[0].args[1]["transition"] = {"duration": 800, "easing": "cubic-in-out"}


fig.update_layout(
    mapbox={"style": "carto-positron", "zoom":2},
    margin={"l": 0, "r": 20, "t": 30, "b": 200}
)



fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 20

### Enregistrer l'image, puis l'ouvrir dans un autre onglet du navigateur
f_address = "interactive_images/birth_places_periods.html"
fig.write_html(f_address)
#fig.show()
plt.close()

# %% [markdown]
# ### Merge persons and territories
#
# This merge provides regions as additional properties of persons

# %%
with open('geo_data/World_Regions_6144914380456424035.geojson') as f:
    geojson = json.load(f)

pprint.pprint(geojson['features'][3]['properties'])
# Out:
# {'FID': 4,
#  'REGION': 'Central America',
#  'SQKM': 2480421.615,
#  'SQMI': 957692.30734}

# %%
print([f['properties']['FID'] for f in geojson['features']][:3])
# Out:
# [1, 2, 3]

# %%
## dataframe GeoPandas from geojson features
world = gpd.GeoDataFrame.from_features(geojson['features'])
### this is needed with this import procedure
world.set_crs(epsg=4326, inplace=True)
world.head()
# Out:
#                                             geometry  FID  \
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...    1
# 1  MULTIPOLYGON (((158.88218 -54.71139, 158.87967...    2
# 2  MULTIPOLYGON (((-60.92305 10.79722, -60.94445 ...    3
# 3  MULTIPOLYGON (((-81.67847 7.38861, -81.64945 7...    4
# 4  POLYGON ((53.90564 37.35086, 53.67731 37.33536...    5
#
#                   REGION          SQMI          SQKM
# 0         Asiatic Russia  4.987737e+06  1.291823e+07
# 1  Australia/New Zealand  3.077219e+06  7.969992e+06
# 2              Caribbean  8.919361e+04  2.310113e+05
# 3        Central America  9.576923e+05  2.480422e+06
# 4           Central Asia  1.612212e+06  4.175626e+06

# %%
### Inspect the projection
pprint.pprint(world.crs)
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world_filepath = 'geo_data/World_Regions_6144914380456424035.geojson'
## dataframe GeoPandas
world = gpd.read_file(world_filepath)
world.head()
# Out:
#    FID                 REGION          SQMI          SQKM  \
# 0    1         Asiatic Russia  4.987737e+06  1.291823e+07
# 1    2  Australia/New Zealand  3.077219e+06  7.969992e+06
# 2    3              Caribbean  8.919361e+04  2.310113e+05
# 3    4        Central America  9.576923e+05  2.480422e+06
# 4    5           Central Asia  1.612212e+06  4.175626e+06
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((158.88218 -54.71139, 158.87967...
# 2  MULTIPOLYGON (((-60.92305 10.79722, -60.94445 ...
# 3  MULTIPOLYGON (((-81.67847 7.38861, -81.64945 7...
# 4  POLYGON ((53.90564 37.35086, 53.67731 37.33536...

# %%
### Cleaned up dataframe
df_p.iloc[[1,5,10]]
# Out:
#                                        uriPer             labelPer  birthYear  \
# 6989  http://www.wikidata.org/entity/Q5400003  Adolphe Hugentobler       1810
# 7904  http://www.wikidata.org/entity/Q6320673       Józef Supiński       1804
# 2698  http://www.wikidata.org/entity/Q1319570         Eugène Buret       1810
#
#      gender  labelPlace                    geometry  \
# 6989   male  Cortaillod   POINT(6.847930 46.943990)
# 7904   male     Romaniv  POINT(24.341389 49.709445)
# 2698   male      Troyes   POINT(4.078056 48.298889)
#
#                                      uriPlace    periods
# 6989    http://www.wikidata.org/entity/Q70308  1801-1810
# 7904  http://www.wikidata.org/entity/Q4397209  1801-1810
# 2698     http://www.wikidata.org/entity/Q5489  1801-1810

# %%
### create a geo data frame

gdf_p = gpd.GeoDataFrame(
    df_p, 
    ### Here we use it
    geometry=gpd.GeoSeries.from_wkt(df_p.geometry), crs=4326
)

gdf_p.head(3)
# Out:
#                                        uriPer             labelPer  birthYear  \
# 7096  http://www.wikidata.org/entity/Q5539301      George Fitzhugh       1806
# 6989  http://www.wikidata.org/entity/Q5400003  Adolphe Hugentobler       1810
# 106   http://www.wikidata.org/entity/Q1031841  Constantin Pecqueur       1801
#
#      gender             labelPlace                  geometry  \
# 7096   male  Prince William County       POINT (-77.48 38.7)
# 6989   male             Cortaillod  POINT (6.84793 46.94399)
# 106    male                 Arleux  POINT (3.10639 50.28028)
#
#                                     uriPlace    periods
# 7096  http://www.wikidata.org/entity/Q183263  1801-1810
# 6989   http://www.wikidata.org/entity/Q70308  1801-1810
# 106    http://www.wikidata.org/entity/Q61573  1801-1810

# %%
### Number of persons before join
print(len(gdf_p))
# Out:
# 9825

# %%
### spatial join : if POINT is inside REGION -> join 
# per person we add the region of birth
pgr_reg = gdf_p.sjoin(world)
pgr_reg.iloc[[1,5,10]]
# Out:
#                                        uriPer             labelPer  birthYear  \
# 6989  http://www.wikidata.org/entity/Q5400003  Adolphe Hugentobler       1810
# 7904  http://www.wikidata.org/entity/Q6320673       Józef Supiński       1804
# 2698  http://www.wikidata.org/entity/Q1319570         Eugène Buret       1810
#
#      gender  labelPlace                   geometry  \
# 6989   male  Cortaillod   POINT (6.84793 46.94399)
# 7904   male     Romaniv  POINT (24.34139 49.70944)
# 2698   male      Troyes   POINT (4.07806 48.29889)
#
#                                      uriPlace    periods  index_right  FID  \
# 6989    http://www.wikidata.org/entity/Q70308  1801-1810           21   22
# 7904  http://www.wikidata.org/entity/Q4397209  1801-1810            7    8
# 2698     http://www.wikidata.org/entity/Q5489  1801-1810           21   22
#
#               REGION          SQMI          SQKM
# 6989  Western Europe  423307.25384  1.096365e+06
# 7904  Eastern Europe  729308.96514  1.888909e+06
# 2698  Western Europe  423307.25384  1.096365e+06

# %%
### There are somme issues with the spatial join and 
### around 600 persons are 'lost'
print(len(pgr_reg))
# Out:
# 9544

# %%
### drop not neede column
pgr_reg = pgr_reg.drop([ 'index_right', 'SQMI','SQKM'], axis=1)
pgr_reg.head(2)
# Out:
#                                        uriPer             labelPer  birthYear  \
# 7096  http://www.wikidata.org/entity/Q5539301      George Fitzhugh       1806
# 6989  http://www.wikidata.org/entity/Q5400003  Adolphe Hugentobler       1810
#
#      gender             labelPlace                  geometry  \
# 7096   male  Prince William County       POINT (-77.48 38.7)
# 6989   male             Cortaillod  POINT (6.84793 46.94399)
#
#                                     uriPlace    periods  FID            REGION
# 7096  http://www.wikidata.org/entity/Q183263  1801-1810   23  Northern America
# 6989   http://www.wikidata.org/entity/Q70308  1801-1810   22    Western Europe

# %% [markdown]
# #### Prepare the data for the bivariate analysis, cf. challenge da3

# %%
file_address='da_data/da3-birthYear-gender-region.csv'
pgr_reg.to_csv(file_address, index=False)

# %% [markdown]
# ## Merge persons and countries

# %%
### Source Eurostat: https://ec.europa.eu/eurostat/web/gisco/geodata/administrative-units/countries
## © EuroGeographics for the administrative boundaries
countries_filepath = 'geo_data/CNTR_RG_03M_2024_4326.geojson'
## dataframe GeoPandas
countries = gpd.read_file(countries_filepath)
countries.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[64], line 5
#       3 countries_filepath = 'geo_data/CNTR_RG_03M_2024_4326.geojson'
#       4 ## dataframe GeoPandas
# ----> 5 countries = gpd.read_file(countries_filepath)
#       6 countries.head()
#
# File ~/my_venvs/data_analysis/lib/python3.12/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File ~/my_venvs/data_analysis/lib/python3.12/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
#     568         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     569         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     572         stacklevel=3,
#     573     )
#     574     kwargs["columns"] = kwargs.pop("include_fields")
# --> 576 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File ~/my_venvs/data_analysis/lib/python3.12/site-packages/pyogrio/geopandas.py:382, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, datetime_as_string, mixed_offsets_as_utc, **kwargs)
#     374 gdal_force_2d = False if use_arrow else force_2d
#     376 # Always read datetimes as string values to preserve (mixed) time zone info
#     377 # correctly. If arrow is not used, it is needed because numpy does not
#     378 # directly support time zones + performance is also a lot better. If arrow
#     379 # is used, needed because datetime columns don't support mixed time zone
#     380 # offsets + e.g. for .fgb files time zone info isn't handled correctly even
#     381 # for unique time zone offsets if datetimes are not read as string.
# --> 382 result = read_func(
#     383     path_or_buffer,
#     384     layer=layer,
#     385     encoding=encoding,
#     386     columns=columns,
#     387     read_geometry=read_geometry,
#     388     force_2d=gdal_force_2d,
#     389     skip_features=skip_features,
#     390     max_features=max_features,
#     391     where=where,
#     392     bbox=bbox,
#     393     mask=mask,
#     394     fids=fids,
#     395     sql=sql,
#     396     sql_dialect=sql_dialect,
#     397     return_fids=fid_as_index,
#     398     datetime_as_string=True,
#     399     **kwargs,
#     400 )
#     402 if use_arrow:
#     403     import pyarrow as pa
#
# File ~/my_venvs/data_analysis/lib/python3.12/site-packages/pyogrio/raw.py:200, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      59 """Read OGR data source into numpy arrays.
#      60
#      61 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)
#     196
#     197 """
#     198 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 200 return ogr_read(
#     201     get_vsi_path_or_buffer(path_or_buffer),
#     202     layer=layer,
#     203     encoding=encoding,
#     204     columns=columns,
#     205     read_geometry=read_geometry,
#     206     force_2d=force_2d,
#     207     skip_features=skip_features,
#     208     max_features=max_features or 0,
#     209     where=where,
#     210     bbox=bbox,
#     211     mask=_mask_to_wkb(mask),
#     212     fids=fids,
#     213     sql=sql,
#     214     sql_dialect=sql_dialect,
#     215     return_fids=return_fids,
#     216     dataset_kwargs=dataset_kwargs,
#     217     datetime_as_string=datetime_as_string,
#     218 )
#
# File pyogrio/_io.pyx:1412, in pyogrio._io.ogr_read()
#
# File pyogrio/_io.pyx:262, in pyogrio._io.ogr_open()
#
# DataSourceError: geo_data/CNTR_RG_03M_2024_4326.geojson: No such file or directory

# %%
countries.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CNTR_ID    263 non-null    object
#  1   CNTR_NAME  263 non-null    object
#  2   NAME_ENGL  263 non-null    object
#  3   NAME_FREN  244 non-null    object
#  4   ISO3_CODE  263 non-null    object
#  5   SVRG_UN    263 non-null    object
#  6   CAPT       233 non-null    object
#  7   EU_STAT    263 non-null    object
#  8   EFTA_STAT  263 non-null    object
#  9   CC_STAT    263 non-null    object
#  10  NAME_GERM  243 non-null    object
#  11  geometry   263 non-null    geometry
# dtypes: geometry(1), object(11)
# memory usage: 24.8+ KB

# %%
pprint.pprint(countries.crs)
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
### Draw the world map with the countries

## GeoPandas documentation
# https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.plot.html

# If we want to exclude the Antarctic region
#countries.clip([-180.0, -10.0, 180.0, 90.0])

ax = countries.plot(color="DarkCyan", alpha=0.2, edgecolor="black", figsize=(15,10))

# If we want to exclude the Antarctic region
ax.set_xlim(-180,180)
ax.set_ylim(-65, 90)


plt.show()

# %%
### spatial join : if POINT is inside REGION -> join 
# per person we add the country of birth
pgr_reg_countries = pgr_reg.sjoin(countries)
pgr_reg_countries.iloc[[1,5,10]]
# Out:
#                                         uriPer                 labelPer  \
# 17614    http://www.wikidata.org/entity/Q62336  Baron Wilhelm von Biela
# 10198   http://www.wikidata.org/entity/Q252265    Theodor von Grotthuss
# 14595  http://www.wikidata.org/entity/Q4740382            Amasa Holcomb
#
#        birthYear gender labelPlace                    geometry  \
# 17614       1782   male      Roßla   POINT (11.07639 51.46472)
# 10198       1785   male    Leipzig   POINT (12.37473 51.34063)
# 14595       1787   male  Southwick  POINT (-72.77083 42.05472)
#
#                                       uriPlace    periods  FID  \
# 17614   http://www.wikidata.org/entity/Q699082  1781-1790   22
# 10198     http://www.wikidata.org/entity/Q2079  1781-1790   22
# 14595  http://www.wikidata.org/entity/Q2302156  1781-1790   23
#
#                  REGION  ...      CNTR_NAME      NAME_ENGL   NAME_FREN  \
# 17614    Western Europe  ...    Deutschland        Germany   Allemagne
# 10198    Western Europe  ...    Deutschland        Germany   Allemagne
# 14595  Northern America  ...  United States  United States  États-Unis
#
#       ISO3_CODE          SVRG_UN              CAPT EU_STAT EFTA_STAT CC_STAT  \
# 17614       DEU  UN Member State            Berlin       T         F       F
# 10198       DEU  UN Member State            Berlin       T         F       F
# 14595       USA  UN Member State  Washington, D.C.       F         F       F
#
#                  NAME_GERM
# 17614          Deutschland
# 10198          Deutschland
# 14595  Vereinigten Staaten
#
# [3 rows x 22 columns]

# %%
### Liyt of column names
pgr_reg_countries.columns
# Out:
# Index(['uriPer', 'labelPer', 'birthYear', 'gender', 'labelPlace', 'geometry',
#        'uriPlace', 'periods', 'FID', 'REGION', 'index_right', 'CNTR_ID',
#        'CNTR_NAME', 'NAME_ENGL', 'NAME_FREN', 'ISO3_CODE', 'SVRG_UN', 'CAPT',
#        'EU_STAT', 'EFTA_STAT', 'CC_STAT', 'NAME_GERM'],
#       dtype='object')

# %%
### drop not needed columns
pgr_reg_countries = pgr_reg_countries.drop([ 'index_right', 'NAME_FREN', 'SVRG_UN', 'CAPT',
       'EU_STAT', 'EFTA_STAT', 'CC_STAT', 'NAME_GERM'], axis=1)
pgr_reg_countries.head(2)
# Out:
#                                        uriPer                 labelPer  \
# 18784  http://www.wikidata.org/entity/Q715984          Joseph Nicollet
# 17614   http://www.wikidata.org/entity/Q62336  Baron Wilhelm von Biela
#
#        birthYear gender labelPlace                   geometry  \
# 18784       1786   male     Cluses   POINT (6.57861 46.06028)
# 17614       1782   male      Roßla  POINT (11.07639 51.46472)
#
#                                      uriPlace    periods  FID          REGION  \
# 18784  http://www.wikidata.org/entity/Q654153  1781-1790   22  Western Europe
# 17614  http://www.wikidata.org/entity/Q699082  1781-1790   22  Western Europe
#
#       CNTR_ID    CNTR_NAME NAME_ENGL ISO3_CODE
# 18784      FR       France    France       FRA
# 17614      DE  Deutschland   Germany       DEU

# %% [markdown]
# ### Clean up gender variable

# %%
pgr_reg_countries.groupby(by='gender').size()
# Out:
# gender
# female                 1654
# male                  19652
# trans man                 1
# trans woman               3
# undisclosed gender        1
# dtype: int64

# %%
### Limit to female/male for statistic treatment
pgr_reg_countries=pgr_reg_countries[pgr_reg_countries.gender.isin(['female', 'male'])]

# %%
pgr_reg_countries.groupby(by='gender').size()
# Out:
# gender
# female     1654
# male      19652
# dtype: int64

# %% [markdown]
# ### Prepare the data for the bivariate analysis, cf. challenge da3

# %%
file_address='da_data/da3-birthYear-gender-region-country.csv'
pgr_reg_countries.to_csv(file_address, index=False)

# %%
### Create columns for long / lat
pgr_reg_countries['long'] = pgr_reg_countries['geometry'].x
pgr_reg_countries['lat'] = pgr_reg_countries['geometry'].y
pgr_reg_countries.head()
# Out:
#                                          uriPer                      labelPer  \
# 15429   http://www.wikidata.org/entity/Q5344785                 Edward Payson
# 11877   http://www.wikidata.org/entity/Q3261578                   Louis Comte
# 15463    http://www.wikidata.org/entity/Q536400  Jacques Philippe Marie Binet
# 11879   http://www.wikidata.org/entity/Q3262997                   Louis Rendu
# 2909   http://www.wikidata.org/entity/Q12026733        Josef Vojtěch Sedláček
#
#        birthYear gender  labelPlace                    geometry  \
# 15429       1783   male      Rindge  POINT (-72.01028 42.74972)
# 11877       1788   male      Geneva           POINT (6.15 46.2)
# 15463       1786   male      Rennes   POINT (-1.68083 48.11417)
# 11879       1789   male      Meyrin    POINT (6.07911 46.23222)
# 2909        1785   male  Čelákovice   POINT (14.75012 50.16045)
#
#                                       uriPlace    periods  FID  \
# 15429  http://www.wikidata.org/entity/Q2419426  1781-1790   23
# 11877       http://www.wikidata.org/entity/Q71  1781-1790   22
# 15463      http://www.wikidata.org/entity/Q647  1781-1790   22
# 11879    http://www.wikidata.org/entity/Q68230  1781-1790   22
# 2909    http://www.wikidata.org/entity/Q338616  1781-1790    8
#
#                  REGION CNTR_ID                       CNTR_NAME  \
# 15429  Northern America      US                   United States
# 11877    Western Europe      CH  Schweiz-Suisse-Svizzera-Svizra
# 15463    Western Europe      FR                          France
# 11879    Western Europe      CH  Schweiz-Suisse-Svizzera-Svizra
# 2909     Eastern Europe      CZ                 Česká Republika
#
#            NAME_ENGL ISO3_CODE       long        lat
# 15429  United States       USA -72.010278  42.749722
# 11877    Switzerland       CHE   6.150000  46.200000
# 15463         France       FRA  -1.680833  48.114167
# 11879    Switzerland       CHE   6.079110  46.232220
# 2909         Czechia       CZE  14.750120  50.160451

# %% [markdown]
# ### Group by regions and periods

# %%
reg_per=pgr_reg.groupby(['FID', 'REGION', 'periods'], observed=True, as_index=False).size()
reg_per.head(3)
# Out:
#    FID          REGION    periods  size
# 0    1  Asiatic Russia  1831-1840     1
# 1    1  Asiatic Russia  1851-1860     3
# 2    1  Asiatic Russia  1871-1880     2

# %%
### Merge with world to get polygons
geom_reg_per=pd.merge(reg_per, world, left_on='FID', right_on='FID')
geom_reg_per=geom_reg_per.drop(['REGION_y','SQMI','SQKM'], axis=1)
geom_reg_per.columns=['FID', 'name','periods','number','geometry']
geom_reg_per.head(2)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1831-1840       1
# 1    1  Asiatic Russia  1851-1860       3
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
### Transform to geoDataFrame
grp_geo = gpd.GeoDataFrame(
    geom_reg_per, 
    crs=4326
)
grp_geo.head(2)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1831-1840       1
# 1    1  Asiatic Russia  1851-1860       3
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
print(len(grp_geo))
# Out:
# 306

# %%
### Tableau de contingence
X = "REGION"
Y = "periods"  # "0"

pv_per_reg = pgr_reg[[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
pv_per_reg
# Out:
# REGION     Asiatic Russia  Australia/New Zealand  Caribbean  Central America  \
# periods
# 1781-1790               0                      0          0                0
# 1791-1800               0                      0          0                0
# 1801-1810               0                      0          0                0
# 1811-1820               0                      0          0                0
# 1821-1830               0                      0          1                0
# 1831-1840               1                      1          0                2
# 1841-1850               0                      1          1                1
# 1851-1860               3                      4          0                2
# 1861-1870               0                      5          0                1
# 1871-1880               2                      5          0                0
# 1881-1890               3                      6          0                1
# 1891-1900               6                      5          2                3
# 1901-1910              18                     13          0                3
# 1911-1920              17                     26          1                8
# 1921-1930              25                     34          0                9
# 1931-1940              45                     22          2               10
# 1941-1950              87                     28          2               17
# 1951-1960              53                     19          2               12
# 1961-1970              15                     13          3               13
# 1971-1980              18                      8          2                6
# Total                 293                    190         16               88
#
# REGION     Central Asia  Eastern Africa  Eastern Asia  Eastern Europe  \
# periods
# 1781-1790             0               0             1              22
# 1791-1800             0               0             0              29
# 1801-1810             0               0             2              34
# 1811-1820             0               0             2              26
# 1821-1830             0               0             0              33
# 1831-1840             0               0             0              42
# 1841-1850             1               0             1              78
# 1851-1860             0               0             5              89
# 1861-1870             1               0             4              85
# 1871-1880             0               0            13             113
# 1881-1890             2               0            19             151
# 1891-1900             1               0            19             167
# 1901-1910             8               1            50             304
# 1911-1920            13               0            80             281
# 1921-1930            19               0           146             563
# 1931-1940            45               3           161             820
# 1941-1950            50               3           117             716
# 1951-1960            22               3           122             496
# 1961-1970            16               3            87             273
# 1971-1980             4               0            33             226
# Total               182              13           862            4548
#
# REGION     European Russia  Micronesia  ...  Polynesia  South America  \
# periods                                 ...
# 1781-1790                4           0  ...          0              0
# 1791-1800                6           0  ...          0              1
# 1801-1810                6           0  ...          0              0
# 1811-1820                7           0  ...          0              2
# 1821-1830                8           0  ...          0              2
# 1831-1840               13           0  ...          0              1
# 1841-1850               21           0  ...          0              3
# 1851-1860               36           0  ...          0              4
# 1861-1870               41           0  ...          0              6
# 1871-1880               37           0  ...          0              2
# 1881-1890               59           0  ...          0              5
# 1891-1900               77           0  ...          0              5
# 1901-1910              170           0  ...          0             12
# 1911-1920              146           0  ...          1             18
# 1921-1930              269           0  ...          0             37
# 1931-1940              343           0  ...          1             44
# 1941-1950              199           1  ...          0             67
# 1951-1960              129           1  ...          0             53
# 1961-1970               48           0  ...          0             45
# 1971-1980               46           0  ...          0             30
# Total                 1665           2  ...          2            337
#
# REGION     Southeastern Asia  Southern Africa  Southern Asia  Southern Europe  \
# periods
# 1781-1790                  0                0              0               19
# 1791-1800                  0                0              0               21
# 1801-1810                  0                0              1               22
# 1811-1820                  0                0              0               30
# 1821-1830                  0                0              3               22
# 1831-1840                  0                2              1               31
# 1841-1850                  1                1              1               39
# 1851-1860                  0                0              1               53
# 1861-1870                  0                0              2               48
# 1871-1880                  2                1              2               72
# 1881-1890                  1                0              7               56
# 1891-1900                  3                2             10               60
# 1901-1910                  3                6             12               88
# 1911-1920                  1                4             17               97
# 1921-1930                  4                9             59              144
# 1931-1940                  8                6             94              203
# 1941-1950                  5                6             84              246
# 1951-1960                  8                2             89              252
# 1961-1970                 10                4             37              258
# 1971-1980                  5                4             25              174
# Total                     51               47            445             1935
#
# REGION     Western Africa  Western Asia  Western Europe  Total
# periods
# 1781-1790               0             0              43    118
# 1791-1800               0             0              72    176
# 1801-1810               0             0              95    216
# 1811-1820               0             0             100    230
# 1821-1830               0             0             115    242
# 1831-1840               0             1             137    310
# 1841-1850               0             1             144    396
# 1851-1860               0             1             198    505
# 1861-1870               0             3             193    547
# 1871-1880               1             5             244    654
# 1881-1890               0            10             264    770
# 1891-1900               1            10             255    839
# 1901-1910               1            25             417   1479
# 1911-1920               0            32             341   1536
# 1921-1930               2            80             591   2642
# 1931-1940               7           128             638   3134
# 1941-1950               6           131             556   2924
# 1951-1960               4           106             460   2214
# 1961-1970               2            57             434   1542
# 1971-1980               3            31             241    971
# Total                  27           621            5538  21445
#
# [21 rows x 24 columns]

# %%
### Table translation
df_t = pv_per_reg.T

# %%
df_t[df_t.Total > 200]
# Out:
# periods           1781-1790  1791-1800  1801-1810  1811-1820  1821-1830  \
# REGION
# Asiatic Russia            0          0          0          0          0
# Eastern Asia              1          0          2          2          0
# Eastern Europe           22         29         34         26         33
# European Russia           4          6          6          7          8
# Northern America          4          7         12         24         18
# Northern Europe          25         40         44         39         40
# South America             0          1          0          2          2
# Southern Asia             0          0          1          0          3
# Southern Europe          19         21         22         30         22
# Western Asia              0          0          0          0          0
# Western Europe           43         72         95        100        115
# Total                   118        176        216        230        242
#
# periods           1831-1840  1841-1850  1851-1860  1861-1870  1871-1880  ...  \
# REGION                                                                   ...
# Asiatic Russia            1          0          3          0          2  ...
# Eastern Asia              0          1          5          4         13  ...
# Eastern Europe           42         78         89         85        113  ...
# European Russia          13         21         36         41         37  ...
# Northern America         29         38         48         82         95  ...
# Northern Europe          49         64         61         76         59  ...
# South America             1          3          4          6          2  ...
# Southern Asia             1          1          1          2          2  ...
# Southern Europe          31         39         53         48         72  ...
# Western Asia              1          1          1          3          5  ...
# Western Europe          137        144        198        193        244  ...
# Total                   310        396        505        547        654  ...
#
# periods           1891-1900  1901-1910  1911-1920  1921-1930  1931-1940  \
# REGION
# Asiatic Russia            6         18         17         25         45
# Eastern Asia             19         50         80        146        161
# Eastern Europe          167        304        281        563        820
# European Russia          77        170        146        269        343
# Northern America        131        221        322        442        375
# Northern Europe          77        125        129        197        161
# South America             5         12         18         37         44
# Southern Asia            10         12         17         59         94
# Southern Europe          60         88         97        144        203
# Western Asia             10         25         32         80        128
# Western Europe          255        417        341        591        638
# Total                   839       1479       1536       2642       3134
#
# periods           1941-1950  1951-1960  1961-1970  1971-1980  Total
# REGION
# Asiatic Russia           87         53         15         18    293
# Eastern Asia            117        122         87         33    862
# Eastern Europe          716        496        273        226   4548
# European Russia         199        129         48         46   1665
# Northern America        401        252        121         63   2795
# Northern Europe         181        111         89         44   1687
# South America            67         53         45         30    337
# Southern Asia            84         89         37         25    445
# Southern Europe         246        252        258        174   1935
# Western Asia            131        106         57         31    621
# Western Europe          556        460        434        241   5538
# Total                  2924       2214       1542        971  21445
#
# [12 rows x 21 columns]

# %%
print(list(df_t.index))
# Out:
# ['Asiatic Russia', 'Australia/New Zealand', 'Caribbean', 'Central America', 'Central Asia', 'Eastern Africa', 'Eastern Asia', 'Eastern Europe', 'European Russia', 'Micronesia', 'Middle Africa', 'Northern Africa', 'Northern America', 'Northern Europe', 'Polynesia', 'South America', 'Southeastern Asia', 'Southern Africa', 'Southern Asia', 'Southern Europe', 'Western Africa', 'Western Asia', 'Western Europe', 'Total']

# %%
grp_geo.head(1)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1831-1840       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
sel_geo = grp_geo[grp_geo.name.isin(list(df_t.index))].copy(deep=True)
sel_geo.head(2)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1831-1840       1
# 1    1  Asiatic Russia  1851-1860       3
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
print(grp_geo.crs)
# Out:
# EPSG:4326

# %%
grp_geo = gpd.GeoDataFrame(
    geom_reg_per, 
    crs=4326
)

### simplify geometry 
## https://www.statology.org/how-to-simplify-geographic-data-using-geopandas/
grp_geo["geometry"] = (
    grp_geo.simplify(tolerance=0.8)
)

# %%
grp_geo=grp_geo.sort_values(by='periods')

# %%
max = grp_geo.number.max()

# Create the choropleth map
fig = px.choropleth_map(
    grp_geo,
    geojson=grp_geo.__geo_interface__,
    locations=grp_geo.index,
    color='number',  # Replace with your actual column name
    color_continuous_scale='Blues',
    range_color=(0, max),  # Replace with your actual range
    zoom=1,
    #map_style='white-bg',
    hover_name='name',
    center={'lat': 47, 'lon': 8.5},
    height=800,
    width=1000,
    animation_frame="periods",
    #title="Temporal evolution of birth regions"

)


fig.update_layout(
    #mapbox={"style": "carto-positron", "zoom":2},
    margin={"l": 0, "r": 20, "t": 30, "b": 200}
)



fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 2000
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 20



f_address = "interactive_images/birth_periods_regions_choropleth.html"
fig.write_html(f_address)
# Show the plot
# fig.show()

# %% [markdown]
# ### Group by regions and periods: only female persons

# %%
reg_per=pgr_reg[pgr_reg.gender=='female'].groupby(['FID', 'REGION', 'periods'], observed=True, as_index=False).size()
reg_per.head(3)
# Out:
#    FID          REGION    periods  size
# 0    1  Asiatic Russia  1891-1900     2
# 1    1  Asiatic Russia  1901-1910     1
# 2    1  Asiatic Russia  1911-1920     3

# %%
### Merge with world to get polygons
geom_reg_per=pd.merge(reg_per, world, left_on='FID', right_on='FID')
geom_reg_per=geom_reg_per.drop(['REGION_y','SQMI','SQKM'], axis=1)
geom_reg_per.columns=['FID', 'name','periods','number','geometry']
geom_reg_per.head(2)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1891-1900       2
# 1    1  Asiatic Russia  1901-1910       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
### Transform to geoDataFrame
grp_geo = gpd.GeoDataFrame(
    geom_reg_per, 
    crs=4326
)
grp_geo.head(2)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1891-1900       2
# 1    1  Asiatic Russia  1901-1910       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
print(len(grp_geo))
# Out:
# 166

# %%
### Tableau de contingence
X = "REGION"
Y = "periods"  # "0"

pv_per_reg = pgr_reg[[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
# pv_per_reg

# %%
### Table translation
df_t = pv_per_reg.T

# %%
# df_t[df_t.Total > 200]

# %%
print(list(df_t.index))
# Out:
# ['Asiatic Russia', 'Australia/New Zealand', 'Caribbean', 'Central America', 'Central Asia', 'Eastern Africa', 'Eastern Asia', 'Eastern Europe', 'European Russia', 'Micronesia', 'Middle Africa', 'Northern Africa', 'Northern America', 'Northern Europe', 'Polynesia', 'South America', 'Southeastern Asia', 'Southern Africa', 'Southern Asia', 'Southern Europe', 'Western Africa', 'Western Asia', 'Western Europe', 'Total']

# %%
grp_geo.head(1)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1891-1900       2
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
sel_geo = grp_geo[grp_geo.name.isin(list(df_t.index))].copy(deep=True)
sel_geo.head(2)
# Out:
#    FID            name    periods  number  \
# 0    1  Asiatic Russia  1891-1900       2
# 1    1  Asiatic Russia  1901-1910       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...
# 1  MULTIPOLYGON (((-179.99999 68.98009, -179.9580...

# %%
print(grp_geo.crs)
# Out:
# EPSG:4326

# %%
grp_geo = gpd.GeoDataFrame(
    geom_reg_per, 
    crs=4326
)

### simplify geometry 
## https://www.statology.org/how-to-simplify-geographic-data-using-geopandas/
grp_geo["geometry"] = (
    grp_geo.simplify(tolerance=0.8)
)

# %%
grp_geo=grp_geo.sort_values(by='periods')

# %%
max = grp_geo.number.max()

# Create the choropleth map
fig = px.choropleth_map(
    grp_geo,
    geojson=grp_geo.__geo_interface__,
    locations=grp_geo.index,
    color='number',  # Replace with your actual column name
    color_continuous_scale='RdPu',
    range_color=(0, max),  # Replace with your actual range
    zoom=1,
    #map_style='white-bg',
    hover_name='name',
    center={'lat': 47, 'lon': 8.5},
    height=800,
    width=1000,
    animation_frame="periods",
    #title="Temporal evolution of birth regions"

)


fig.update_layout(
    #mapbox={"style": "carto-positron", "zoom":2},
    margin={"l": 0, "r": 20, "t": 30, "b": 200}
)



fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 2000
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 20



f_address = "interactive_images/birth_periods_regions_choropleth_female.html"
fig.write_html(f_address)
# Show the plot
# fig.show()
